# %% [markdown]
# <a href="https://colab.research.google.com/github/tenshianimefrangel/prueba/blob/master/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/thunil/TecoGAN.git
# Out:
# Cloning into 'TecoGAN'...
# remote: Enumerating objects: 149, done.
# remote: Total 149 (delta 0), reused 0 (delta 0), pack-reused 149
# Receiving objects: 100% (149/149), 19.87 MiB | 7.95 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
